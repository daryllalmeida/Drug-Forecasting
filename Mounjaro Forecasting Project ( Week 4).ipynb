# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns

# %%
df = pd.read_excel('Mounjaro Data.xlsx')

# %% [markdown]
# # Week 1: Data Exploration & Set up of the Project.

# %%
df.head()
# Out:
#   Month, Year of week ending date  Volume Sold - East  Volume Sold - West  \
# 0                      2020-01-01             580.481            220.1030
# 1                      2020-02-01             563.638            161.7300
# 2                      2020-03-01             568.605            190.9875
# 3                      2020-04-01             574.849            194.8790
# 4                      2020-05-01             695.019            276.1740
#
#    Volume Sold - South  Volume Sold - Midwest  Total Volume Sold
# 0             341.4920               359.7310           1501.807
# 1             283.3785               313.4245           1322.171
# 2             312.2535               350.0440           1421.890
# 3             316.1860               356.3410           1442.255
# 4             422.6145               402.7915           1796.599

# %%
df.tail()
# Out:
#    Month, Year of week ending date  Volume Sold - East  Volume Sold - West  \
# 51                      2024-04-01           4509.7055           2570.2245
# 52                      2024-05-01           6034.4480           3501.0880
# 53                      2024-06-01           4831.8710           3030.2275
# 54                      2024-07-01           4748.4775           2609.4560
# 55                      2024-08-01           3564.6370           1765.1660
#
#     Volume Sold - South  Volume Sold - Midwest  Total Volume Sold
# 51            3449.8270              4498.0915         15027.8485
# 52            5196.3055              6307.3720         21039.2135
# 53            4391.1545              5249.8620         17503.1150
# 54            3762.8665              4798.5925         15919.3925
# 55            1878.4145              2943.7155         10151.9330

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Month, Year of week ending date  56 non-null     datetime64[ns]
#  1   Volume Sold - East               56 non-null     float64
#  2   Volume Sold - West               56 non-null     float64
#  3   Volume Sold - South              56 non-null     float64
#  4   Volume Sold - Midwest            56 non-null     float64
#  5   Total Volume Sold                56 non-null     float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 2.8 KB

# %%
df.dtypes
# Out:
# Month, Year of week ending date    datetime64[ns]
# Volume Sold - East                        float64
# Volume Sold - West                        float64
# Volume Sold - South                       float64
# Volume Sold - Midwest                     float64
# Total Volume Sold                         float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Month, Year of week ending date    0
# Volume Sold - East                 0
# Volume Sold - West                 0
# Volume Sold - South                0
# Volume Sold - Midwest              0
# Total Volume Sold                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
duplicated_row = df[df.duplicated()]
duplicated_row
# Out:
#    Month, Year of week ending date  Volume Sold - East  Volume Sold - West  \
# 18                      2021-07-01            1659.037            611.1325
#
#     Volume Sold - South  Volume Sold - Midwest  Total Volume Sold
# 18              795.301               1212.565          4278.0355

# %%
df.head(30)
# Out:
#    Month, Year of week ending date  Volume Sold - East  Volume Sold - West  \
# 0                       2020-01-01            580.4810            220.1030
# 1                       2020-02-01            563.6380            161.7300
# 2                       2020-03-01            568.6050            190.9875
# 3                       2020-04-01            574.8490            194.8790
# 4                       2020-05-01            695.0190            276.1740
# 5                       2020-06-01            642.3145            247.8220
# 6                       2020-08-01            676.7035            272.1830
# 7                       2020-09-01            620.6850            220.7355
# 8                       2020-10-01            892.4715            393.8955
# 9                       2020-11-01            746.8080            289.8285
# 10                      2020-12-01            783.6345            310.4885
# 11                      2021-01-01           1079.1540            422.0570
# 12                      2021-02-01            842.9580            360.5955
# 13                      2021-03-01            916.4830            396.2740
# 14                      2021-04-01           1239.4575            439.7405
# 15                      2021-05-01           1173.7755            431.3950
# 16                      2021-06-01           1303.1100            484.5940
# 17                      2021-07-01           1659.0370            611.1325
# 18                      2021-07-01           1659.0370            611.1325
# 19                      2021-08-01           1480.3970            552.1740
# 20                      2021-09-01           1546.8165            584.1775
# 21                      2021-10-01           2031.4420            803.9715
# 22                      2021-11-01           1758.8140            700.5530
# 23                      2021-12-01           2413.1280            908.5710
# 24                      2022-01-01           1938.4075            734.3370
# 25                      2022-02-01           1970.7555            755.4460
# 26                      2022-03-01           2244.0650            859.1605
# 27                      2022-04-01           2865.1565           1276.9905
# 28                      2022-05-01           2540.7955           1183.5660
# 29                      2022-06-01           2768.5450           1202.3275
#
#     Volume Sold - South  Volume Sold - Midwest  Total Volume Sold
# 0              341.4920               359.7310          1501.8070
# 1              283.3785               313.4245          1322.1710
# 2              312.2535               350.0440          1421.8900
# 3              316.1860               356.3410          1442.2550
# 4              422.6145               402.7915          1796.5990
# 5              360.9805               394.1560          1645.2730
# 6              383.0140               398.5955          1730.4960
# 7              360.1145               372.5570          1574.0920
# 8              511.1435               562.6380          2360.1485
# 9              433.9220               412.4770          1883.0355
# 10             438.8550               472.6485          2005.6265
# 11             573.7310               687.0145          2761.9565
# 12             486.9600               497.2620          2187.7755
# 13             527.1330               676.5755          2516.4655
# 14             623.4665               772.0940          3074.7585
# 15             610.9810               718.9170          2935.0685
# 16             685.0375               835.4250          3308.1665
# 17             795.3010              1212.5650          4278.0355
# 18             795.3010              1212.5650          4278.0355
# 19             685.5610              1049.1820          3767.3140
# 20             777.5445              1139.4340          4047.9725
# 21            1047.2905              1525.7720          5408.4760
# 22             888.7970              1251.5670          4599.7310
# 23            1180.6850              1776.4345          6278.8185
# 24             899.9540              1402.9315          4975.6300
# 25            1004.2580              1478.8140          5209.2735
# 26            1089.0220              1686.0025          5878.2500
# 27            1449.6600              2169.8960          7761.7030
# 28            1294.8150              1933.3600          6952.5365
# 29            1399.6625              2169.4580          7539.9930

# %%
#Removing the duplicated row

df = df.drop(index = 18)

# %%
df.head(30)
# Out:
#    Month, Year of week ending date  Volume Sold - East  Volume Sold - West  \
# 0                       2020-01-01            580.4810            220.1030
# 1                       2020-02-01            563.6380            161.7300
# 2                       2020-03-01            568.6050            190.9875
# 3                       2020-04-01            574.8490            194.8790
# 4                       2020-05-01            695.0190            276.1740
# 5                       2020-06-01            642.3145            247.8220
# 6                       2020-08-01            676.7035            272.1830
# 7                       2020-09-01            620.6850            220.7355
# 8                       2020-10-01            892.4715            393.8955
# 9                       2020-11-01            746.8080            289.8285
# 10                      2020-12-01            783.6345            310.4885
# 11                      2021-01-01           1079.1540            422.0570
# 12                      2021-02-01            842.9580            360.5955
# 13                      2021-03-01            916.4830            396.2740
# 14                      2021-04-01           1239.4575            439.7405
# 15                      2021-05-01           1173.7755            431.3950
# 16                      2021-06-01           1303.1100            484.5940
# 17                      2021-07-01           1659.0370            611.1325
# 19                      2021-08-01           1480.3970            552.1740
# 20                      2021-09-01           1546.8165            584.1775
# 21                      2021-10-01           2031.4420            803.9715
# 22                      2021-11-01           1758.8140            700.5530
# 23                      2021-12-01           2413.1280            908.5710
# 24                      2022-01-01           1938.4075            734.3370
# 25                      2022-02-01           1970.7555            755.4460
# 26                      2022-03-01           2244.0650            859.1605
# 27                      2022-04-01           2865.1565           1276.9905
# 28                      2022-05-01           2540.7955           1183.5660
# 29                      2022-06-01           2768.5450           1202.3275
# 30                      2022-07-01           3514.1645           1714.3470
#
#     Volume Sold - South  Volume Sold - Midwest  Total Volume Sold
# 0              341.4920               359.7310          1501.8070
# 1              283.3785               313.4245          1322.1710
# 2              312.2535               350.0440          1421.8900
# 3              316.1860               356.3410          1442.2550
# 4              422.6145               402.7915          1796.5990
# 5              360.9805               394.1560          1645.2730
# 6              383.0140               398.5955          1730.4960
# 7              360.1145               372.5570          1574.0920
# 8              511.1435               562.6380          2360.1485
# 9              433.9220               412.4770          1883.0355
# 10             438.8550               472.6485          2005.6265
# 11             573.7310               687.0145          2761.9565
# 12             486.9600               497.2620          2187.7755
# 13             527.1330               676.5755          2516.4655
# 14             623.4665               772.0940          3074.7585
# 15             610.9810               718.9170          2935.0685
# 16             685.0375               835.4250          3308.1665
# 17             795.3010              1212.5650          4278.0355
# 19             685.5610              1049.1820          3767.3140
# 20             777.5445              1139.4340          4047.9725
# 21            1047.2905              1525.7720          5408.4760
# 22             888.7970              1251.5670          4599.7310
# 23            1180.6850              1776.4345          6278.8185
# 24             899.9540              1402.9315          4975.6300
# 25            1004.2580              1478.8140          5209.2735
# 26            1089.0220              1686.0025          5878.2500
# 27            1449.6600              2169.8960          7761.7030
# 28            1294.8150              1933.3600          6952.5365
# 29            1399.6625              2169.4580          7539.9930
# 30            1845.2660              2890.2020          9963.9795

# %%
#Generating summary statistics

summary = df[['Volume Sold - East','Volume Sold - West','Volume Sold - Midwest','Volume Sold - South', 'Total Volume Sold']].describe()

# %%
summary
# Out:
#        Volume Sold - East  Volume Sold - West  Volume Sold - Midwest  \
# count           55.000000           55.000000              55.000000
# mean          2831.699945         1468.899209            2568.671945
# std           1781.026783         1126.583893            1988.655806
# min            563.638000          161.730000             313.424500
# 25%           1126.464750          426.726000             702.965750
# 50%           2768.545000         1202.327500            2169.458000
# 75%           4376.071250         2460.015250            4269.962000
# max           6221.659500         3841.101500            6723.577000
#
#        Volume Sold - South  Total Volume Sold
# count            55.000000          55.000000
# mean           1965.542073        8834.813173
# std            1609.620102        6479.779109
# min             283.378500        1322.171000
# 25%             592.356000        2848.512500
# 50%            1399.662500        7539.993000
# 75%            3312.753500       14418.802000
# max            5610.439500       22396.777500

# %%
#Visualizations


Total_volume_sold = df[['Volume Sold - East','Volume Sold - West','Volume Sold - Midwest','Volume Sold - South','Total Volume Sold']].sum()

plt.figure(figsize=(8, 6))
ax = Total_volume_sold.plot(kind='bar', color=['purple', 'orange', 'magenta', 'red','skyblue'])
Total_volume_sold.plot(kind='bar', color=['purple', 'orange', 'magenta', 'red','skyblue'])
plt.title('Total Sales by Region')
plt.ylabel('Total Sales')
plt.xlabel('Region')

for i in ax.patches:
    ax.text(i.get_x() + i.get_width() / 2,  
            i.get_height() + 0.5,          
            f'{i.get_height():.0f}',       
            ha='center',                   
            va='bottom',                   
            fontsize=10,                  
            color='black') 

plt.show()

# %% [markdown]
# <h1> Inferences </h1>
#
# <h2>From this graph we can see that majority of the sales occured across the East region and the Midwest region. </h2>

# %%
sns.pairplot(df[['Volume Sold - East','Volume Sold - West','Volume Sold - Midwest','Volume Sold - South','Total Volume Sold']])
plt.suptitle('Pairplot of Sales')
plt.show()

# %% [markdown]
# <h1> Inferences </h1>
#
# <h2> This pairplot shows us a positive correlation across each region with the slope in an upward direction. </h2>

# %%
#Histogram

df[['Volume Sold - East', 'Volume Sold - West', 'Volume Sold - South', 'Volume Sold - Midwest','Total Volume Sold']].hist(bins=20, figsize=(10, 8))
plt.title('Sales Distribution across US')
plt.show()

# %% [markdown]
# <b> We can see that in all the plots the data points are majorly distributed towards the left side of the plots and we can say that it is positively skewed. </b>

# %%
#Boxplot

plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Volume Sold - East', 'Volume Sold - West', 'Volume Sold - South', 'Volume Sold - Midwest','Total Volume Sold']])
plt.title('Sales Distribution Across Regions')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# <h1> Inferences </h1>
#
# <b> The East shows that the volumes lie from 1000 to <4500 whereas West has volumes ranging from 500 to 2500. South has volume ranging from >500 to <3500 & Midwest has volume ranging from >500 and <4500. The data is not skewed in any column since all of the median points do not lie at the lower or the upper ends of the boxplots. </b>

# %%
# QQ Plot for Normality

east_data = df['Volume Sold - East']

stats.probplot(east_data, dist="norm", plot=plt)
plt.title('QQ Plot for Sales Data - East Region')
plt.ylabel('Ordered Values')
plt.show()

# %%
# QQ Plot for Normality

west_data = df['Volume Sold - West']

stats.probplot(west_data, dist="norm", plot=plt)
plt.title('QQ Plot for Sales Data - West Region')
plt.ylabel('Ordered Values')
plt.show()

# %%
# QQ Plot for Normality

south_data = df['Volume Sold - South']

stats.probplot(south_data, dist="norm", plot=plt)
plt.title('QQ Plot for Sales Data - South Region')
plt.ylabel('Ordered Values')
plt.show()

# %%
# QQ Plot for Normality

midwest_data = df['Volume Sold - Midwest']

stats.probplot(midwest_data, dist="norm", plot=plt)
plt.title('QQ Plot for Sales Data - Midwest Region')
plt.ylabel('Ordered Values')
plt.show()

# %%
# QQ Plot for Normality

total_area = df['Total Volume Sold']

stats.probplot(total_area, dist="norm", plot=plt)
plt.title('QQ Plot for Sales Data - Total')
plt.ylabel('Ordered Values')
plt.show()

# %% [markdown]
# <h1> Inferences </h1>
#
# <b> The lines for all of the areas form a wave like patternwhich indicates that the data is not following a normal
# distribution and also indicates that the data follows a cyclic/periodic behavioural pattern. </b>

# %%
# Acf plot
from statsmodels.graphics.tsaplots import plot_acf

plt.figure(figsize=(10, 6))
plot_acf(east_data, lags=40)  
plt.title('ACF Plot for Sales Data - East Region')
plt.show()

# Acf plot
from statsmodels.graphics.tsaplots import plot_acf

plt.figure(figsize=(10, 6))
plot_acf(west_data, lags=40)  
plt.title('ACF Plot for Sales Data - West Region')
plt.show()

# Acf plot
from statsmodels.graphics.tsaplots import plot_acf

plt.figure(figsize=(10, 6))
plot_acf(south_data, lags=40)  
plt.title('ACF Plot for Sales Data - South Region')
plt.show()

# Acf plot
from statsmodels.graphics.tsaplots import plot_acf

plt.figure(figsize=(10, 6))
plot_acf(midwest_data, lags=40)  
plt.title('ACF Plot for Sales Data - Midwest Region')
plt.show()

#Acf plot
from statsmodels.graphics.tsaplots import plot_acf

plt.figure(figsize=(10, 6))
plot_acf(total_area, lags=40)  
plt.title('ACF Plot for Sales Data - Total Area')
plt.show()

# %% [markdown]
# <h1> Inferences </h1>
#
# <b> There is a gradual decrease in the plot values which suggests the presence of trends or cyclical patterns in the sales data. </b>

# %%
df.set_index('Month, Year of week ending date', inplace=True)

# %%
#Time Series plots

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))

axes = axes.flatten()

regions = ['Volume Sold - East', 'Volume Sold - West', 'Volume Sold - South', 'Volume Sold - Midwest', 
           'Total Volume Sold']

for ax, region in zip(axes, regions):
    ax.plot(df.index, df[region], label=region, color='blue')
    ax.set_title(region)
    ax.set_xlabel('Date')
    ax.set_ylabel('Volume Sold')
    ax.legend()
    ax.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1> Inferences </h1>
#
# <b> The plots show us that there a minimal increase from 2020 to 2022 but after that we see that the volumes have increased tremendously.
# There also has been periods where there was a steep decrease in volume sold for each region from 2022 to 2024. </b>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))


plt.plot(df.index, df['Volume Sold - East'], label='Volume Sold - East', color='green')
plt.plot(df.index, df['Volume Sold - West'], label='Volume Sold - West', color='blue')
plt.plot(df.index, df['Volume Sold - South'], label='Volume Sold - South', color='purple')
plt.plot(df.index, df['Volume Sold - Midwest'], label='Volume Sold - Midwest', color='red')
plt.plot(df.index, df['Total Volume Sold'], label='Total Volume Sold', color='black')

plt.title('Sales Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume Sold')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Week 2 : Data Cleaning and Preprocessing

# %%
#checking if the data is stationary

from statsmodels.tsa.stattools import adfuller

result = adfuller(df['Total Volume Sold'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -1.4428219252960828
# p-value: 0.5615834346156521

# %% [markdown]
# <h2> Inferences </h2>
#
# <b> From the ADF test, we can see that the p-value is greater than 0.05 which indicates that the data is not stationary. In this case, we would be doing the differencing to convert this non-stationary data into stationary. </b>

# %%
df['Total Volume Diff'] = df['Total Volume Sold'].diff()
df.dropna(inplace=True)

# %%
result_diff = adfuller(df['Total Volume Diff'])
print('ADF Statistic:', result_diff[0])
print('p-value:', result_diff[1])
# Out:
# ADF Statistic: -1.1202343511100785
# p-value: 0.7069355997545426

# %% [markdown]
# <h2> Inferences </h2>
#
# <b> Here, the p value has not gone below 0.05 so we need to difference it again to ensure stationarity. </b>

# %%
df['Total Volume Diff2'] = df['Total Volume Diff'].diff()
df.dropna(inplace=True)

# %%
result_diff2 = adfuller(df['Total Volume Diff2'])
print('ADF Statistic:', result_diff2[0])
print('p-value:', result_diff2[1])
# Out:
# ADF Statistic: -4.353159076624482
# p-value: 0.00035891692449874804

# %% [markdown]
# <h2> Inferences </h2>
#
# <b> We can now say that the data is stationary since a p-value of 0.00035 indicates that the data is good enough to be considered stationary. </b>

# %%
#Performing Decomposition on the differenced data


df.head(10)
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2020-03-01                                 568.6050            190.9875
# 2020-04-01                                 574.8490            194.8790
# 2020-05-01                                 695.0190            276.1740
# 2020-06-01                                 642.3145            247.8220
# 2020-08-01                                 676.7035            272.1830
# 2020-09-01                                 620.6850            220.7355
# 2020-10-01                                 892.4715            393.8955
# 2020-11-01                                 746.8080            289.8285
# 2020-12-01                                 783.6345            310.4885
# 2021-01-01                                1079.1540            422.0570
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2020-03-01                                  312.2535               350.0440
# 2020-04-01                                  316.1860               356.3410
# 2020-05-01                                  422.6145               402.7915
# 2020-06-01                                  360.9805               394.1560
# 2020-08-01                                  383.0140               398.5955
# 2020-09-01                                  360.1145               372.5570
# 2020-10-01                                  511.1435               562.6380
# 2020-11-01                                  433.9220               412.4770
# 2020-12-01                                  438.8550               472.6485
# 2021-01-01                                  573.7310               687.0145
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2020-03-01                               1421.8900            99.7190
# 2020-04-01                               1442.2550            20.3650
# 2020-05-01                               1796.5990           354.3440
# 2020-06-01                               1645.2730          -151.3260
# 2020-08-01                               1730.4960            85.2230
# 2020-09-01                               1574.0920          -156.4040
# 2020-10-01                               2360.1485           786.0565
# 2020-11-01                               1883.0355          -477.1130
# 2020-12-01                               2005.6265           122.5910
# 2021-01-01                               2761.9565           756.3300
#
#                                  Total Volume Diff2
# Month, Year of week ending date
# 2020-03-01                                 279.3550
# 2020-04-01                                 -79.3540
# 2020-05-01                                 333.9790
# 2020-06-01                                -505.6700
# 2020-08-01                                 236.5490
# 2020-09-01                                -241.6270
# 2020-10-01                                 942.4605
# 2020-11-01                               -1263.1695
# 2020-12-01                                 599.7040
# 2021-01-01                                 633.7390

# %%
df.describe()
# Out:
#        Volume Sold - East  Volume Sold - West  Volume Sold - South  \
# count           53.000000           53.000000            53.000000
# mean          2916.969396         1517.124972          2027.923462
# std           1757.913960         1119.279317          1606.680118
# min            568.605000          190.987500           312.253500
# 25%           1239.457500          439.740500           623.466500
# 50%           2865.156500         1276.990500          1449.660000
# 75%           4457.136500         2499.404500          3313.677000
# max           6221.659500         3841.101500          5610.439500
#
#        Volume Sold - Midwest  Total Volume Sold  Total Volume Diff  \
# count              53.000000          53.000000          53.000000
# mean             2652.901915        9114.919745         166.599283
# std              1976.861459        6434.516118        3111.041806
# min               350.044000        1421.890000       -7477.375500
# 25%               772.094000        3074.758500       -1036.024500
# 50%              2169.896000        7761.703000         122.591000
# 75%              4294.539500       14564.757500        1360.503500
# max              6723.577000       22396.777500        7015.673000
#
#        Total Volume Diff2
# count           53.000000
# mean          -105.430632
# std           5204.154056
# min         -14435.937000
# 25%          -1480.590500
# 50%            596.771000
# 75%           1952.376000
# max           9942.185500

# %%
# Correlation matrix
correlation_matrix = df[['Volume Sold - East', 'Volume Sold - West', 'Volume Sold - Midwest', 'Volume Sold - South',
                         'Total Volume Sold']].corr()


sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Between Sales')
plt.show()

# %% [markdown]
# <h1> Inferences </h1>
#
# <b> From the correlation matrix, we can see that mostly all of the columns have a high correlation between them. This means that the regions do not exhibit any independent features between them and they all are dependant. </b>

# %%
plt.figure(figsize=(10, 6))
df['Total Volume Sold'].plot()
plt.title('Total Volume Sold Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales Volume')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

#Decomposition on the total volume sold column
decomposition = seasonal_decompose(df['Total Volume Sold'], model='additive', period=12)

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(14, 13))

decomposition.observed.plot(ax=axes[0], legend=False)
axes[0].set_title('Observed')
axes[0].set_ylabel('Total Volume Sold')

decomposition.trend.plot(ax=axes[1], legend=False)
axes[1].set_title('Trend')
axes[1].set_ylabel('Total Volume Sold')

decomposition.seasonal.plot(ax=axes[2], legend=False)
axes[2].set_title('Seasonal')
axes[2].set_ylabel('Total Volume Sold')

decomposition.resid.plot(ax=axes[3], legend=False)
axes[3].set_title('Residual')
axes[3].set_ylabel('Total Volume Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1> Inferences : Observed Plot </h1>
#
# <b> 1. For the observed values, we see that initially the product took a bit of time to get established in the market till 2022 after which sales started growing rapidly across USA. This can be due to improved market conditions, better product awareness. </b>
# <br>
# <b> 2. We can also see that there is a volatile component too in the graph because of the spikes post 2022. </b>

# %% [markdown]
# <h1> Inferences : Seasonal Plot </h1>
#
# <b> We can see that the data does have seasonality as the pattern keeps fluctuating after a particular period of time </b>

# %% [markdown]
# <h1> Inferences : Residuals </h1>
#
# <b> The residual plot shows us that there is fluctuating data which means that all of the data may not be captured by decomposition. </b>

# %%
#Finding the outliers using z score method

z_scores = stats.zscore(df['Total Volume Sold'])
outliers = df[(z_scores > 3) | (z_scores < -3)]

# %%
print("Outliers:")
print(outliers)
# Out:
# Outliers:
# Empty DataFrame
# Columns: [Volume Sold - East, Volume Sold - West, Volume Sold - South, Volume Sold - Midwest, Total Volume Sold, Total Volume Diff, Total Volume Diff2]
# Index: []

# %% [markdown]
# <b> This indicates that we were unable to find the outliers and the dataset seems to be stable & consistent. </b>

# %%
df.head()
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2020-03-01                                 568.6050            190.9875
# 2020-04-01                                 574.8490            194.8790
# 2020-05-01                                 695.0190            276.1740
# 2020-06-01                                 642.3145            247.8220
# 2020-08-01                                 676.7035            272.1830
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2020-03-01                                  312.2535               350.0440
# 2020-04-01                                  316.1860               356.3410
# 2020-05-01                                  422.6145               402.7915
# 2020-06-01                                  360.9805               394.1560
# 2020-08-01                                  383.0140               398.5955
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2020-03-01                                1421.890             99.719
# 2020-04-01                                1442.255             20.365
# 2020-05-01                                1796.599            354.344
# 2020-06-01                                1645.273           -151.326
# 2020-08-01                                1730.496             85.223
#
#                                  Total Volume Diff2
# Month, Year of week ending date
# 2020-03-01                                  279.355
# 2020-04-01                                  -79.354
# 2020-05-01                                  333.979
# 2020-06-01                                 -505.670
# 2020-08-01                                  236.549

# %% [markdown]
# # Week 3 : EDA and Feature Engineering

# %% [markdown]
# <b>Since we need our data to find the residuals entirely, i am performing a comparision to check if an additive model would be best or multiplicative model would work better. </b>

# %%
# Additive Decomposition
additive_decomposition = seasonal_decompose(df['Total Volume Sold'], model='additive', period=12)
additive_residuals = additive_decomposition.resid.dropna()


print("Additive Residuals:")
print(additive_residuals.describe())
# Out:
# Additive Residuals:
# count      41.000000
# mean       52.634232
# std      1535.581425
# min     -2862.802366
# 25%      -846.491268
# 50%      -237.337054
# 75%      1057.227802
# max      4556.317941
# Name: resid, dtype: float64

# %%
# Multiplicative Decomposition

multiplicative_decomposition = seasonal_decompose(df['Total Volume Sold'], model='multiplicative', period=12)
multiplicative_residuals = multiplicative_decomposition.resid.dropna()


print("Multiplicative Residuals:")
print(multiplicative_residuals.describe())
# Out:
# Multiplicative Residuals:
# count    41.000000
# mean      0.992184
# std       0.120310
# min       0.765087
# 25%       0.918926
# 50%       0.983597
# 75%       1.044752
# max       1.274792
# Name: resid, dtype: float64

# %%
#Additive
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(additive_residuals, label='Additive Residuals', color = 'green')
plt.title('Additive Model Residuals')
plt.legend()


#multiplicative
plt.subplot(2, 1, 2)
plt.plot(multiplicative_residuals, label='Multiplicative Residuals', color='red')
plt.title('Multiplicative Model Residuals')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1> Inferences </h1>
#
#
# <b> We can conclude from this plot and the statistics that a multiplicative model would be the best for the residuals as it has a lower mean and a standard deviation as compared to the Additive mnodel.</b>

# %%
from statsmodels.graphics.tsaplots import plot_acf

# Plot ACF for residuals
plt.figure(figsize=(10, 6))
plot_acf(decomposition.resid.dropna(), lags=40)
plt.title('ACF of Residuals - Multiplicative Decomposition')
plt.show()

# %% [markdown]
# <h1> Inferences from the ACF plot : </h1>
#
# <b> Most points lie within the confidence interval of the ACF plot and from this we can confirm that the model is capturing all the Residuals now </b>

# %%
decomposition = seasonal_decompose(df['Total Volume Sold'], model = 'multiplicative', period = 12)

residual_values = decomposition.resid.dropna()

# %%
#Adding a lag feature to the dataset since the Ljung-box test p value is less than 0.05

df['lag_1'] = df['Total Volume Sold'].shift(1)  # This references 1 month
df['lag_2'] = df['Total Volume Sold'].shift(2)  # This references previous 2 months
df['lag_3'] = df['Total Volume Sold'].shift(3)  # This references previous 3 months


df[['Total Volume Sold', 'lag_1', 'lag_2', 'lag_3']].head(10)
# Out:
#                                  Total Volume Sold      lag_1      lag_2  \
# Month, Year of week ending date
# 2020-03-01                               1421.8900        NaN        NaN
# 2020-04-01                               1442.2550  1421.8900        NaN
# 2020-05-01                               1796.5990  1442.2550  1421.8900
# 2020-06-01                               1645.2730  1796.5990  1442.2550
# 2020-08-01                               1730.4960  1645.2730  1796.5990
# 2020-09-01                               1574.0920  1730.4960  1645.2730
# 2020-10-01                               2360.1485  1574.0920  1730.4960
# 2020-11-01                               1883.0355  2360.1485  1574.0920
# 2020-12-01                               2005.6265  1883.0355  2360.1485
# 2021-01-01                               2761.9565  2005.6265  1883.0355
#
#                                      lag_3
# Month, Year of week ending date
# 2020-03-01                             NaN
# 2020-04-01                             NaN
# 2020-05-01                             NaN
# 2020-06-01                       1421.8900
# 2020-08-01                       1442.2550
# 2020-09-01                       1796.5990
# 2020-10-01                       1645.2730
# 2020-11-01                       1730.4960
# 2020-12-01                       1574.0920
# 2021-01-01                       2360.1485

# %%
#Dropping the NAN value rows

df = df.dropna()

# %%
df.head()
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2020-06-01                                 642.3145            247.8220
# 2020-08-01                                 676.7035            272.1830
# 2020-09-01                                 620.6850            220.7355
# 2020-10-01                                 892.4715            393.8955
# 2020-11-01                                 746.8080            289.8285
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2020-06-01                                  360.9805               394.1560
# 2020-08-01                                  383.0140               398.5955
# 2020-09-01                                  360.1145               372.5570
# 2020-10-01                                  511.1435               562.6380
# 2020-11-01                                  433.9220               412.4770
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2020-06-01                               1645.2730          -151.3260
# 2020-08-01                               1730.4960            85.2230
# 2020-09-01                               1574.0920          -156.4040
# 2020-10-01                               2360.1485           786.0565
# 2020-11-01                               1883.0355          -477.1130
#
#                                  Total Volume Diff2      lag_1     lag_2  \
# Month, Year of week ending date
# 2020-06-01                                -505.6700  1796.5990  1442.255
# 2020-08-01                                 236.5490  1645.2730  1796.599
# 2020-09-01                                -241.6270  1730.4960  1645.273
# 2020-10-01                                 942.4605  1574.0920  1730.496
# 2020-11-01                               -1263.1695  2360.1485  1574.092
#
#                                     lag_3
# Month, Year of week ending date
# 2020-06-01                       1421.890
# 2020-08-01                       1442.255
# 2020-09-01                       1796.599
# 2020-10-01                       1645.273
# 2020-11-01                       1730.496

# %%
#Adding a moving average feature of 3,6,12 months to understand short term fluctuations and long term.

df['MA_3'] = df['Total Volume Sold'].rolling(window=3).mean()

df['MA_6'] = df['Total Volume Sold'].rolling(window=6).mean()

df['MA_12'] = df['Total Volume Sold'].rolling(window=12).mean()

df[['Total Volume Sold', 'MA_3', 'MA_6', 'MA_12']].head(20)
# Out:
#                                  Total Volume Sold         MA_3         MA_6  \
# Month, Year of week ending date
# 2020-06-01                               1645.2730          NaN          NaN
# 2020-08-01                               1730.4960          NaN          NaN
# 2020-09-01                               1574.0920  1649.953667          NaN
# 2020-10-01                               2360.1485  1888.245500          NaN
# 2020-11-01                               1883.0355  1939.092000          NaN
# 2020-12-01                               2005.6265  2082.936833  1866.445250
# 2021-01-01                               2761.9565  2216.872833  2052.559167
# 2021-02-01                               2187.7755  2318.452833  2128.772417
# 2021-03-01                               2516.4655  2488.732500  2285.834667
# 2021-04-01                               3074.7585  2592.999833  2404.936333
# 2021-05-01                               2935.0685  2842.097500  2580.275167
# 2021-06-01                               3308.1665  3105.997833  2797.365167
# 2021-07-01                               4278.0355  3507.090167  3050.045000
# 2021-08-01                               3767.3140  3784.505333  3313.301417
# 2021-09-01                               4047.9725  4031.107333  3568.552583
# 2021-10-01                               5408.4760  4407.920833  3957.505500
# 2021-11-01                               4599.7310  4685.393167  4234.949250
# 2021-12-01                               6278.8185  5429.008500  4730.057917
# 2022-01-01                               4975.6300  5284.726500  4846.323667
# 2022-02-01                               5209.2735  5487.907333  5086.650250
#
#                                        MA_12
# Month, Year of week ending date
# 2020-06-01                               NaN
# 2020-08-01                               NaN
# 2020-09-01                               NaN
# 2020-10-01                               NaN
# 2020-11-01                               NaN
# 2020-12-01                               NaN
# 2021-01-01                               NaN
# 2021-02-01                               NaN
# 2021-03-01                               NaN
# 2021-04-01                               NaN
# 2021-05-01                               NaN
# 2021-06-01                       2331.905208
# 2021-07-01                       2551.302083
# 2021-08-01                       2721.036917
# 2021-09-01                       2927.193625
# 2021-10-01                       3181.220917
# 2021-11-01                       3407.612208
# 2021-12-01                       3763.711542
# 2022-01-01                       3948.184333
# 2022-02-01                       4199.975833

# %%
#Removing NA values

df = df.dropna(subset=['MA_3','MA_6','MA_12'])

# %%
df.head(5)
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2021-06-01                                1303.1100            484.5940
# 2021-07-01                                1659.0370            611.1325
# 2021-08-01                                1480.3970            552.1740
# 2021-09-01                                1546.8165            584.1775
# 2021-10-01                                2031.4420            803.9715
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2021-06-01                                  685.0375                835.425
# 2021-07-01                                  795.3010               1212.565
# 2021-08-01                                  685.5610               1049.182
# 2021-09-01                                  777.5445               1139.434
# 2021-10-01                                 1047.2905               1525.772
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2021-06-01                               3308.1665           373.0980
# 2021-07-01                               4278.0355           969.8690
# 2021-08-01                               3767.3140          -510.7215
# 2021-09-01                               4047.9725           280.6585
# 2021-10-01                               5408.4760          1360.5035
#
#                                  Total Volume Diff2      lag_1      lag_2  \
# Month, Year of week ending date
# 2021-06-01                                 512.7880  2935.0685  3074.7585
# 2021-07-01                                 596.7710  3308.1665  2935.0685
# 2021-08-01                               -1480.5905  4278.0355  3308.1665
# 2021-09-01                                 791.3800  3767.3140  4278.0355
# 2021-10-01                                1079.8450  4047.9725  3767.3140
#
#                                      lag_3         MA_3         MA_6  \
# Month, Year of week ending date
# 2021-06-01                       2516.4655  3105.997833  2797.365167
# 2021-07-01                       3074.7585  3507.090167  3050.045000
# 2021-08-01                       2935.0685  3784.505333  3313.301417
# 2021-09-01                       3308.1665  4031.107333  3568.552583
# 2021-10-01                       4278.0355  4407.920833  3957.505500
#
#                                        MA_12
# Month, Year of week ending date
# 2021-06-01                       2331.905208
# 2021-07-01                       2551.302083
# 2021-08-01                       2721.036917
# 2021-09-01                       2927.193625
# 2021-10-01                       3181.220917

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Total Volume Sold'], label='Total Volume Sold', color='blue')
plt.plot(df['MA_3'], label='3-Month Moving Average', color='orange')
plt.plot(df['MA_6'], label='6-Month Moving Average', color='green')
plt.plot(df['MA_12'], label='12-Month Moving Average', color='red')
plt.title('Total Volume Sold with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Volume Sold')
plt.legend()
plt.show()

# %% [markdown]
# <h1> Inferences </h1>
#
# <b> The yellow line tell us that the short term sales trend matches with the Total volume sold graph & it shows consistent growth after January 2023.
# The increase after January 2023 tells us that sales were on the rising during this period.</b>
#
# <b> The green line is a much more smoothed out line which indicates that the sales are more gradual over the period of time. This line also shows the spike at a later stage as compared to the 3 month yellow line.</b>
#
# <b> The gradual increase of the red line suggests that the long-term trend in sales is improving. We can see that the red line does not have a decrease which indicates that the drug gained good amount of traction & it's also possible that there were good marketing strategies being run during that time.</b>

# %%
#Seasonal lag feature

df['Sales_Last_Year'] = df['Total Volume Sold'].shift(12)

# %% [markdown]
# <b> This seasonal lag feature will capture the sales value from a previous time period </b>

# %%
df['Sales_Last_Year'].head(20)
# Out:
# Month, Year of week ending date
# 2021-06-01          NaN
# 2021-07-01          NaN
# 2021-08-01          NaN
# 2021-09-01          NaN
# 2021-10-01          NaN
# 2021-11-01          NaN
# 2021-12-01          NaN
# 2022-01-01          NaN
# 2022-02-01          NaN
# 2022-03-01          NaN
# 2022-04-01          NaN
# 2022-05-01          NaN
# 2022-06-01    3308.1665
# 2022-07-01    4278.0355
# 2022-08-01    3767.3140
# 2022-09-01    4047.9725
# 2022-10-01    5408.4760
# 2022-11-01    4599.7310
# 2022-12-01    6278.8185
# 2023-01-01    4975.6300
# Name: Sales_Last_Year, dtype: float64

# %%
df.dropna(inplace = True)

# %%
df['Sales_Last_Year'].head(20)
# Out:
# Month, Year of week ending date
# 2022-06-01     3308.1665
# 2022-07-01     4278.0355
# 2022-08-01     3767.3140
# 2022-09-01     4047.9725
# 2022-10-01     5408.4760
# 2022-11-01     4599.7310
# 2022-12-01     6278.8185
# 2023-01-01     4975.6300
# 2023-02-01     5209.2735
# 2023-03-01     5878.2500
# 2023-04-01     7761.7030
# 2023-05-01     6952.5365
# 2023-06-01     7539.9930
# 2023-07-01     9963.9795
# 2023-08-01     8044.4840
# 2023-09-01    11791.1385
# 2023-10-01     9245.2180
# 2023-11-01     8209.1935
# 2023-12-01    13634.6575
# 2024-01-01    10595.2750
# Name: Sales_Last_Year, dtype: float64

# %%
df.head()
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2022-06-01                                2768.5450           1202.3275
# 2022-07-01                                3514.1645           1714.3470
# 2022-08-01                                2915.4455           1385.1905
# 2022-09-01                                3909.5145           2019.9965
# 2022-10-01                                3213.6615           1655.9880
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2022-06-01                                 1399.6625               2169.458
# 2022-07-01                                 1845.2660               2890.202
# 2022-08-01                                 1501.4880               2242.360
# 2022-09-01                                 2401.1825               3460.445
# 2022-10-01                                 1815.7755               2559.793
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2022-06-01                               7539.9930           587.4565
# 2022-07-01                               9963.9795          2423.9865
# 2022-08-01                               8044.4840         -1919.4955
# 2022-09-01                              11791.1385          3746.6545
# 2022-10-01                               9245.2180         -2545.9205
#
#                                  Total Volume Diff2       lag_1      lag_2  \
# Month, Year of week ending date
# 2022-06-01                                 1396.623   6952.5365  7761.7030
# 2022-07-01                                 1836.530   7539.9930  6952.5365
# 2022-08-01                                -4343.482   9963.9795  7539.9930
# 2022-09-01                                 5666.150   8044.4840  9963.9795
# 2022-10-01                                -6292.575  11791.1385  8044.4840
#
#                                      lag_3         MA_3         MA_6  \
# Month, Year of week ending date
# 2022-06-01                       5878.2500  7418.077500  6386.231000
# 2022-07-01                       7761.7030  8152.169667  7217.622583
# 2022-08-01                       6952.5365  8516.152167  7690.157667
# 2022-09-01                       7539.9930  9933.200667  8675.639083
# 2022-10-01                       9963.9795  9693.613500  8922.891583
#
#                                        MA_12  Sales_Last_Year
# Month, Year of week ending date
# 2022-06-01                       5558.144458        3308.1665
# 2022-07-01                       6031.973125        4278.0355
# 2022-08-01                       6388.403958        3767.3140
# 2022-09-01                       7033.667792        4047.9725
# 2022-10-01                       7353.396292        5408.4760

# %%
#Comparision between this year sales and last year sales

df['Sales_Change_YoY'] = df['Total Volume Sold'] - df['Sales_Last_Year']

df.head(10)
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2022-06-01                                2768.5450           1202.3275
# 2022-07-01                                3514.1645           1714.3470
# 2022-08-01                                2915.4455           1385.1905
# 2022-09-01                                3909.5145           2019.9965
# 2022-10-01                                3213.6615           1655.9880
# 2022-11-01                                3016.5190           1385.7345
# 2022-12-01                                4229.1930           2250.6215
# 2023-01-01                                3588.3865           1827.4735
# 2023-02-01                                3830.8030           1900.5875
# 2023-03-01                                5186.0105           3174.1630
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2022-06-01                                 1399.6625              2169.4580
# 2022-07-01                                 1845.2660              2890.2020
# 2022-08-01                                 1501.4880              2242.3600
# 2022-09-01                                 2401.1825              3460.4450
# 2022-10-01                                 1815.7755              2559.7930
# 2022-11-01                                 1531.7065              2275.2335
# 2022-12-01                                 3013.6910              4141.1520
# 2023-01-01                                 2086.4285              3092.9865
# 2023-02-01                                 2359.5850              3417.0745
# 2023-03-01                                 4503.7980              5659.7515
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2022-06-01                               7539.9930           587.4565
# 2022-07-01                               9963.9795          2423.9865
# 2022-08-01                               8044.4840         -1919.4955
# 2022-09-01                              11791.1385          3746.6545
# 2022-10-01                               9245.2180         -2545.9205
# 2022-11-01                               8209.1935         -1036.0245
# 2022-12-01                              13634.6575          5425.4640
# 2023-01-01                              10595.2750         -3039.3825
# 2023-02-01                              11508.0500           912.7750
# 2023-03-01                              18523.7230          7015.6730
#
#                                  Total Volume Diff2       lag_1       lag_2  \
# Month, Year of week ending date
# 2022-06-01                                1396.6230   6952.5365   7761.7030
# 2022-07-01                                1836.5300   7539.9930   6952.5365
# 2022-08-01                               -4343.4820   9963.9795   7539.9930
# 2022-09-01                                5666.1500   8044.4840   9963.9795
# 2022-10-01                               -6292.5750  11791.1385   8044.4840
# 2022-11-01                                1509.8960   9245.2180  11791.1385
# 2022-12-01                                6461.4885   8209.1935   9245.2180
# 2023-01-01                               -8464.8465  13634.6575   8209.1935
# 2023-02-01                                3952.1575  10595.2750  13634.6575
# 2023-03-01                                6102.8980  11508.0500  10595.2750
#
#                                       lag_3          MA_3          MA_6  \
# Month, Year of week ending date
# 2022-06-01                        5878.2500   7418.077500   6386.231000
# 2022-07-01                        7761.7030   8152.169667   7217.622583
# 2022-08-01                        6952.5365   8516.152167   7690.157667
# 2022-09-01                        7539.9930   9933.200667   8675.639083
# 2022-10-01                        9963.9795   9693.613500   8922.891583
# 2022-11-01                        8044.4840   9748.516667   9132.334417
# 2022-12-01                       11791.1385  10363.023000  10148.111833
# 2023-01-01                        9245.2180  10813.042000  10253.327750
# 2023-02-01                        8209.1935  11912.660833  10830.588750
# 2023-03-01                       13634.6575  13542.349333  11952.686167
#
#                                         MA_12  Sales_Last_Year  \
# Month, Year of week ending date
# 2022-06-01                        5558.144458        3308.1665
# 2022-07-01                        6031.973125        4278.0355
# 2022-08-01                        6388.403958        3767.3140
# 2022-09-01                        7033.667792        4047.9725
# 2022-10-01                        7353.396292        5408.4760
# 2022-11-01                        7654.184833        4599.7310
# 2022-12-01                        8267.171417        6278.8185
# 2023-01-01                        8735.475167        4975.6300
# 2023-02-01                        9260.373208        5209.2735
# 2023-03-01                       10314.162625        5878.2500
#
#                                  Sales_Change_YoY
# Month, Year of week ending date
# 2022-06-01                              4231.8265
# 2022-07-01                              5685.9440
# 2022-08-01                              4277.1700
# 2022-09-01                              7743.1660
# 2022-10-01                              3836.7420
# 2022-11-01                              3609.4625
# 2022-12-01                              7355.8390
# 2023-01-01                              5619.6450
# 2023-02-01                              6298.7765
# 2023-03-01                             12645.4730

# %%
df.head()
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2022-06-01                                2768.5450           1202.3275
# 2022-07-01                                3514.1645           1714.3470
# 2022-08-01                                2915.4455           1385.1905
# 2022-09-01                                3909.5145           2019.9965
# 2022-10-01                                3213.6615           1655.9880
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2022-06-01                                 1399.6625               2169.458
# 2022-07-01                                 1845.2660               2890.202
# 2022-08-01                                 1501.4880               2242.360
# 2022-09-01                                 2401.1825               3460.445
# 2022-10-01                                 1815.7755               2559.793
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2022-06-01                               7539.9930           587.4565
# 2022-07-01                               9963.9795          2423.9865
# 2022-08-01                               8044.4840         -1919.4955
# 2022-09-01                              11791.1385          3746.6545
# 2022-10-01                               9245.2180         -2545.9205
#
#                                  Total Volume Diff2       lag_1      lag_2  \
# Month, Year of week ending date
# 2022-06-01                                 1396.623   6952.5365  7761.7030
# 2022-07-01                                 1836.530   7539.9930  6952.5365
# 2022-08-01                                -4343.482   9963.9795  7539.9930
# 2022-09-01                                 5666.150   8044.4840  9963.9795
# 2022-10-01                                -6292.575  11791.1385  8044.4840
#
#                                      lag_3         MA_3         MA_6  \
# Month, Year of week ending date
# 2022-06-01                       5878.2500  7418.077500  6386.231000
# 2022-07-01                       7761.7030  8152.169667  7217.622583
# 2022-08-01                       6952.5365  8516.152167  7690.157667
# 2022-09-01                       7539.9930  9933.200667  8675.639083
# 2022-10-01                       9963.9795  9693.613500  8922.891583
#
#                                        MA_12  Sales_Last_Year  \
# Month, Year of week ending date
# 2022-06-01                       5558.144458        3308.1665
# 2022-07-01                       6031.973125        4278.0355
# 2022-08-01                       6388.403958        3767.3140
# 2022-09-01                       7033.667792        4047.9725
# 2022-10-01                       7353.396292        5408.4760
#
#                                  Sales_Change_YoY
# Month, Year of week ending date
# 2022-06-01                              4231.8265
# 2022-07-01                              5685.9440
# 2022-08-01                              4277.1700
# 2022-09-01                              7743.1660
# 2022-10-01                              3836.7420

# %%
# Moving Standard Deviation

df['Moving_Std_3'] = df['Total Volume Sold'].rolling(window=3).std()

# %%
df.head(10)
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2022-06-01                                2768.5450           1202.3275
# 2022-07-01                                3514.1645           1714.3470
# 2022-08-01                                2915.4455           1385.1905
# 2022-09-01                                3909.5145           2019.9965
# 2022-10-01                                3213.6615           1655.9880
# 2022-11-01                                3016.5190           1385.7345
# 2022-12-01                                4229.1930           2250.6215
# 2023-01-01                                3588.3865           1827.4735
# 2023-02-01                                3830.8030           1900.5875
# 2023-03-01                                5186.0105           3174.1630
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2022-06-01                                 1399.6625              2169.4580
# 2022-07-01                                 1845.2660              2890.2020
# 2022-08-01                                 1501.4880              2242.3600
# 2022-09-01                                 2401.1825              3460.4450
# 2022-10-01                                 1815.7755              2559.7930
# 2022-11-01                                 1531.7065              2275.2335
# 2022-12-01                                 3013.6910              4141.1520
# 2023-01-01                                 2086.4285              3092.9865
# 2023-02-01                                 2359.5850              3417.0745
# 2023-03-01                                 4503.7980              5659.7515
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2022-06-01                               7539.9930           587.4565
# 2022-07-01                               9963.9795          2423.9865
# 2022-08-01                               8044.4840         -1919.4955
# 2022-09-01                              11791.1385          3746.6545
# 2022-10-01                               9245.2180         -2545.9205
# 2022-11-01                               8209.1935         -1036.0245
# 2022-12-01                              13634.6575          5425.4640
# 2023-01-01                              10595.2750         -3039.3825
# 2023-02-01                              11508.0500           912.7750
# 2023-03-01                              18523.7230          7015.6730
#
#                                  Total Volume Diff2       lag_1       lag_2  \
# Month, Year of week ending date
# 2022-06-01                                1396.6230   6952.5365   7761.7030
# 2022-07-01                                1836.5300   7539.9930   6952.5365
# 2022-08-01                               -4343.4820   9963.9795   7539.9930
# 2022-09-01                                5666.1500   8044.4840   9963.9795
# 2022-10-01                               -6292.5750  11791.1385   8044.4840
# 2022-11-01                                1509.8960   9245.2180  11791.1385
# 2022-12-01                                6461.4885   8209.1935   9245.2180
# 2023-01-01                               -8464.8465  13634.6575   8209.1935
# 2023-02-01                                3952.1575  10595.2750  13634.6575
# 2023-03-01                                6102.8980  11508.0500  10595.2750
#
#                                       lag_3          MA_3          MA_6  \
# Month, Year of week ending date
# 2022-06-01                        5878.2500   7418.077500   6386.231000
# 2022-07-01                        7761.7030   8152.169667   7217.622583
# 2022-08-01                        6952.5365   8516.152167   7690.157667
# 2022-09-01                        7539.9930   9933.200667   8675.639083
# 2022-10-01                        9963.9795   9693.613500   8922.891583
# 2022-11-01                        8044.4840   9748.516667   9132.334417
# 2022-12-01                       11791.1385  10363.023000  10148.111833
# 2023-01-01                        9245.2180  10813.042000  10253.327750
# 2023-02-01                        8209.1935  11912.660833  10830.588750
# 2023-03-01                       13634.6575  13542.349333  11952.686167
#
#                                         MA_12  Sales_Last_Year  \
# Month, Year of week ending date
# 2022-06-01                        5558.144458        3308.1665
# 2022-07-01                        6031.973125        4278.0355
# 2022-08-01                        6388.403958        3767.3140
# 2022-09-01                        7033.667792        4047.9725
# 2022-10-01                        7353.396292        5408.4760
# 2022-11-01                        7654.184833        4599.7310
# 2022-12-01                        8267.171417        6278.8185
# 2023-01-01                        8735.475167        4975.6300
# 2023-02-01                        9260.373208        5209.2735
# 2023-03-01                       10314.162625        5878.2500
#
#                                  Sales_Change_YoY  Moving_Std_3
# Month, Year of week ending date
# 2022-06-01                              4231.8265           NaN
# 2022-07-01                              5685.9440           NaN
# 2022-08-01                              4277.1700   1278.976459
# 2022-09-01                              7743.1660   1873.516877
# 2022-10-01                              3836.7420   1913.151557
# 2022-11-01                              3609.4625   1843.248398
# 2022-12-01                              7355.8390   2880.283131
# 2023-01-01                              5619.6450   2719.279639
# 2023-02-01                              6298.7765   1559.565305
# 2023-03-01                             12645.4730   4338.070107

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2022-08-01                                2915.4455           1385.1905
# 2022-09-01                                3909.5145           2019.9965
# 2022-10-01                                3213.6615           1655.9880
# 2022-11-01                                3016.5190           1385.7345
# 2022-12-01                                4229.1930           2250.6215
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2022-08-01                                 1501.4880              2242.3600
# 2022-09-01                                 2401.1825              3460.4450
# 2022-10-01                                 1815.7755              2559.7930
# 2022-11-01                                 1531.7065              2275.2335
# 2022-12-01                                 3013.6910              4141.1520
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2022-08-01                               8044.4840         -1919.4955
# 2022-09-01                              11791.1385          3746.6545
# 2022-10-01                               9245.2180         -2545.9205
# 2022-11-01                               8209.1935         -1036.0245
# 2022-12-01                              13634.6575          5425.4640
#
#                                  Total Volume Diff2       lag_1       lag_2  \
# Month, Year of week ending date
# 2022-08-01                               -4343.4820   9963.9795   7539.9930
# 2022-09-01                                5666.1500   8044.4840   9963.9795
# 2022-10-01                               -6292.5750  11791.1385   8044.4840
# 2022-11-01                                1509.8960   9245.2180  11791.1385
# 2022-12-01                                6461.4885   8209.1935   9245.2180
#
#                                       lag_3          MA_3          MA_6  \
# Month, Year of week ending date
# 2022-08-01                        6952.5365   8516.152167   7690.157667
# 2022-09-01                        7539.9930   9933.200667   8675.639083
# 2022-10-01                        9963.9795   9693.613500   8922.891583
# 2022-11-01                        8044.4840   9748.516667   9132.334417
# 2022-12-01                       11791.1385  10363.023000  10148.111833
#
#                                        MA_12  Sales_Last_Year  \
# Month, Year of week ending date
# 2022-08-01                       6388.403958        3767.3140
# 2022-09-01                       7033.667792        4047.9725
# 2022-10-01                       7353.396292        5408.4760
# 2022-11-01                       7654.184833        4599.7310
# 2022-12-01                       8267.171417        6278.8185
#
#                                  Sales_Change_YoY  Moving_Std_3
# Month, Year of week ending date
# 2022-08-01                              4277.1700   1278.976459
# 2022-09-01                              7743.1660   1873.516877
# 2022-10-01                              3836.7420   1913.151557
# 2022-11-01                              3609.4625   1843.248398
# 2022-12-01                              7355.8390   2880.283131

# %% [markdown]
# <b> The moving standard deviation feature can be useful to capture the volatility in the dataset </b>

# %%
# Creating a new feature to calculate the % change of sales

df['Sales_Change'] = df['Total Volume Sold'].pct_change()

# %%
df.head()
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2022-08-01                                2915.4455           1385.1905
# 2022-09-01                                3909.5145           2019.9965
# 2022-10-01                                3213.6615           1655.9880
# 2022-11-01                                3016.5190           1385.7345
# 2022-12-01                                4229.1930           2250.6215
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2022-08-01                                 1501.4880              2242.3600
# 2022-09-01                                 2401.1825              3460.4450
# 2022-10-01                                 1815.7755              2559.7930
# 2022-11-01                                 1531.7065              2275.2335
# 2022-12-01                                 3013.6910              4141.1520
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2022-08-01                               8044.4840         -1919.4955
# 2022-09-01                              11791.1385          3746.6545
# 2022-10-01                               9245.2180         -2545.9205
# 2022-11-01                               8209.1935         -1036.0245
# 2022-12-01                              13634.6575          5425.4640
#
#                                  Total Volume Diff2       lag_1       lag_2  \
# Month, Year of week ending date
# 2022-08-01                               -4343.4820   9963.9795   7539.9930
# 2022-09-01                                5666.1500   8044.4840   9963.9795
# 2022-10-01                               -6292.5750  11791.1385   8044.4840
# 2022-11-01                                1509.8960   9245.2180  11791.1385
# 2022-12-01                                6461.4885   8209.1935   9245.2180
#
#                                       lag_3          MA_3          MA_6  \
# Month, Year of week ending date
# 2022-08-01                        6952.5365   8516.152167   7690.157667
# 2022-09-01                        7539.9930   9933.200667   8675.639083
# 2022-10-01                        9963.9795   9693.613500   8922.891583
# 2022-11-01                        8044.4840   9748.516667   9132.334417
# 2022-12-01                       11791.1385  10363.023000  10148.111833
#
#                                        MA_12  Sales_Last_Year  \
# Month, Year of week ending date
# 2022-08-01                       6388.403958        3767.3140
# 2022-09-01                       7033.667792        4047.9725
# 2022-10-01                       7353.396292        5408.4760
# 2022-11-01                       7654.184833        4599.7310
# 2022-12-01                       8267.171417        6278.8185
#
#                                  Sales_Change_YoY  Moving_Std_3  Sales_Change
# Month, Year of week ending date
# 2022-08-01                              4277.1700   1278.976459           NaN
# 2022-09-01                              7743.1660   1873.516877      0.465742
# 2022-10-01                              3836.7420   1913.151557     -0.215918
# 2022-11-01                              3609.4625   1843.248398     -0.112061
# 2022-12-01                              7355.8390   2880.283131      0.660901

# %% [markdown]
# # Week 4 : Model Building

# %%
#Ljung Box test

from statsmodels.stats.diagnostic import acorr_ljungbox

lb_test = acorr_ljungbox(df['Total Volume Sold'], lags=[20], return_df=True)
print(lb_test)
# Out:
#       lb_stat  lb_pvalue
# 20  33.414945   0.030366

# %% [markdown]
# <h1> Inferences </h1>
#
# <b> The p value tells us that the Ljung box test is below the p-value of 0.05 and we can reject the null hypothesis. It does tell us that there is auto-correlation. </b>

# %% [markdown]
# <h1> Creating a baseline model </h1>

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/darylldalmeida/anaconda3/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in /Users/darylldalmeida/anaconda3/lib/python3.11/site-packages (from statsmodels) (1.24.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /Users/darylldalmeida/anaconda3/lib/python3.11/site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: pandas>=1.0 in /Users/darylldalmeida/anaconda3/lib/python3.11/site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/darylldalmeida/anaconda3/lib/python3.11/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/darylldalmeida/anaconda3/lib/python3.11/site-packages (from statsmodels) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/darylldalmeida/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/darylldalmeida/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2022.7)
# Requirement already satisfied: six in /Users/darylldalmeida/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %%
#Naive forecast column

df['Naive_forecast'] = df['Total Volume Sold'].shift(1)

# %%
#Moving average forecast column

df['MA_forecast'] = df['Total Volume Sold'].rolling(window = 3).mean()

# %%
df.head()
# Out:
#                                  Volume Sold - East  Volume Sold - West  \
# Month, Year of week ending date
# 2022-08-01                                2915.4455           1385.1905
# 2022-09-01                                3909.5145           2019.9965
# 2022-10-01                                3213.6615           1655.9880
# 2022-11-01                                3016.5190           1385.7345
# 2022-12-01                                4229.1930           2250.6215
#
#                                  Volume Sold - South  Volume Sold - Midwest  \
# Month, Year of week ending date
# 2022-08-01                                 1501.4880              2242.3600
# 2022-09-01                                 2401.1825              3460.4450
# 2022-10-01                                 1815.7755              2559.7930
# 2022-11-01                                 1531.7065              2275.2335
# 2022-12-01                                 3013.6910              4141.1520
#
#                                  Total Volume Sold  Total Volume Diff  \
# Month, Year of week ending date
# 2022-08-01                               8044.4840         -1919.4955
# 2022-09-01                              11791.1385          3746.6545
# 2022-10-01                               9245.2180         -2545.9205
# 2022-11-01                               8209.1935         -1036.0245
# 2022-12-01                              13634.6575          5425.4640
#
#                                  Total Volume Diff2       lag_1       lag_2  \
# Month, Year of week ending date
# 2022-08-01                               -4343.4820   9963.9795   7539.9930
# 2022-09-01                                5666.1500   8044.4840   9963.9795
# 2022-10-01                               -6292.5750  11791.1385   8044.4840
# 2022-11-01                                1509.8960   9245.2180  11791.1385
# 2022-12-01                                6461.4885   8209.1935   9245.2180
#
#                                       lag_3          MA_3          MA_6  \
# Month, Year of week ending date
# 2022-08-01                        6952.5365   8516.152167   7690.157667
# 2022-09-01                        7539.9930   9933.200667   8675.639083
# 2022-10-01                        9963.9795   9693.613500   8922.891583
# 2022-11-01                        8044.4840   9748.516667   9132.334417
# 2022-12-01                       11791.1385  10363.023000  10148.111833
#
#                                        MA_12  Sales_Last_Year  \
# Month, Year of week ending date
# 2022-08-01                       6388.403958        3767.3140
# 2022-09-01                       7033.667792        4047.9725
# 2022-10-01                       7353.396292        5408.4760
# 2022-11-01                       7654.184833        4599.7310
# 2022-12-01                       8267.171417        6278.8185
#
#                                  Sales_Change_YoY  Moving_Std_3  Sales_Change  \
# Month, Year of week ending date
# 2022-08-01                              4277.1700   1278.976459           NaN
# 2022-09-01                              7743.1660   1873.516877      0.465742
# 2022-10-01                              3836.7420   1913.151557     -0.215918
# 2022-11-01                              3609.4625   1843.248398     -0.112061
# 2022-12-01                              7355.8390   2880.283131      0.660901
#
#                                  Naive_forecast   MA_forecast
# Month, Year of week ending date
# 2022-08-01                                  NaN           NaN
# 2022-09-01                            8044.4840           NaN
# 2022-10-01                           11791.1385   9693.613500
# 2022-11-01                            9245.2180   9748.516667
# 2022-12-01                            8209.1935  10363.023000

# %%
df.dropna(inplace = True)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error


mae_naive = mean_absolute_error(df['Total Volume Sold'], df['Naive_forecast'])
mae_ma = mean_absolute_error(df['Total Volume Sold'], df['MA_forecast'])


mse_naive = mean_squared_error(df['Total Volume Sold'], df['Naive_forecast'])
mse_ma = mean_squared_error(df['Total Volume Sold'], df['MA_forecast'])

print(f"Naive Forecast MAE: {mae_naive}, MA Forecast MAE: {mae_ma}")
# Out:
# Naive Forecast MAE: 3973.8492826086976, MA Forecast MAE: 2173.863050724639

# %%
# Display summary statistics for 'Total Volume Sold'
total_volume_stats = df['Total Volume Sold'].describe()
print(total_volume_stats)
# Out:
# count       23.000000
# mean     15389.121935
# std       3927.095509
# min       8209.193500
# 25%      13279.382250
# 50%      15027.848500
# 75%      18222.212250
# max      22396.777500
# Name: Total Volume Sold, dtype: float64

# %% [markdown]
# <h1> Inferences </h1>
#
# <b> The total volume sold statistics tells us that the mean volume is around 15,389 units with the minimum and maximum values being 8209 and 22396 respectively. </b>

# %% [markdown]
# <b> The Naive forecast MAE tells us that out of 15,389 units sold, there is an error in 3974 units which is approximately 26% whereas the Moving Average Forecast MAE it tells us that the error is 14% since the value is 2174. Hence , we can proceed with the MA Forecast MAE since it gives us a better % value for the baseline model. MAE of 2174 for the Moving Average forecast means that the prediction is off by around 2174 units on an average & is better than the Naive MAE. </b>

# %% [markdown]
# <b> The reason why i am going ahead with choosing MAE over any other Forecast like Naive or MAPE is because it is quite robust to outliers and is giving me a better indication than the others. This would be a good choice to determine the forecasting models performance too. </b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Month, Year of week ending date  23 non-null     datetime64[ns]
#  1   Volume Sold - East               23 non-null     float64
#  2   Volume Sold - West               23 non-null     float64
#  3   Volume Sold - South              23 non-null     float64
#  4   Volume Sold - Midwest            23 non-null     float64
#  5   Total Volume Sold                23 non-null     float64
#  6   Total Volume Diff                23 non-null     float64
#  7   Total Volume Diff2               23 non-null     float64
#  8   lag_1                            23 non-null     float64
#  9   lag_2                            23 non-null     float64
#  10  lag_3                            23 non-null     float64
#  11  MA_3                             23 non-null     float64
#  12  MA_6                             23 non-null     float64
#  13  MA_12                            23 non-null     float64
#  14  Sales_Last_Year                  23 non-null     float64
#  15  Sales_Change_YoY                 23 non-null     float64
#  16  Moving_Std_3                     23 non-null     float64
#  17  Sales_Change                     23 non-null     float64
#  18  Naive_forecast                   23 non-null     float64
#  19  MA_forecast                      23 non-null     float64
# dtypes: datetime64[ns](1), float64(19)
# memory usage: 3.7 KB

# %%
plt.figure(figsize=(10,6))

# Plot the actual sales
plt.plot(df['Month, Year of week ending date'], df['Total Volume Sold'], label='Actual Sales', marker='o')

# Plot the naive forecast
plt.plot(df['Month, Year of week ending date'], df['Naive_forecast'], label='Naive Forecast', marker='x')

# Plot the MA forecast
plt.plot(df['Month, Year of week ending date'], df['MA_forecast'], label='Moving Average Forecast', marker='*')

# Add titles and labels
plt.title('Actual Sales vs Forecasted Values')
plt.xlabel('Month, Year of week ending date')
plt.ylabel('Total Volume Sold')
plt.legend()

plt.show()

# %% [markdown]
# <h1>Inferences </h1>
#
# <b> I can see that from this graph, the Moving Average forecast MAE is quite smoother as compared to the Naive Forecast MAE when it comes to comparing it with the Actual Sales. This indicates more stability for Moving Average MAE.

# %%
mae_ma = mean_absolute_error(df['Total Volume Sold'], df['MA_forecast'])
mse_ma = mean_squared_error(df['Total Volume Sold'], df['MA_forecast'])
mape_ma = np.mean(np.abs((df['Total Volume Sold'] - df['MA_forecast']) / df['Total Volume Sold'])) * 100

# %%
print(mae_ma)
print(mse_ma)
print(mape_ma)
# Out:
# 2173.863050724639
# 7293589.870750837
# 14.09868271943426

# %%
df['error_ma'] = df['Total Volume Sold'] - df['MA_forecast']
plt.figure(figsize=(10,6))
plt.plot(df['Month, Year of week ending date'], df['error_ma'], label='Moving Average Forecast Error')
plt.title('Moving Average Forecast Error Over Time')
plt.xlabel('Month, Year of week ending date')
plt.ylabel('Forecast Error')
plt.legend()
plt.show()
